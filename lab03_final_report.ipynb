# %% [markdown]
# <h1><center>
#     ECE 438: Digital Signal Processing with Applications<br/>
#     Lab 3: Frequency Analysis<br/>
#     <small>Date: 1/31/2023</small><br/>
#     <small>Section:Tuesday 8:30am</small><br>
# </center></h1>

# %% [markdown]
# |Name |Signature |Time spent outside lab|
# |:---:|:---:|:---:|
# |Justin Wang [100%]| |4 hours|

# %% [markdown]
# ||Below expectations| Lacks in some respect|Meets all expectations|
# |:---:|:---:|:---:|:---:|
# |**Completeness of the report**||||
# |**Organization of the report**||||
# |**Quality of figures**: *Correctly labeled with title, x-axis, y-axis, and name(s)*||||
# |**Ability to compute Fourier series expansion and synthesize periodic signals using the expansion in Simulink (26 pts)**: *Derivation and sketch, plots of synthesized signals, questions*||||
# |**Understanding of modulator and CT system analysis (26 pts)**: *Output plots, questions*||||
# |**Implementation of DTFT (21 pts)**: *Python function, DTFT’s magnitude and phase plots*||||
# |**DT system analysis (27 pts)**: *Exercises in 5.2, completed block diagram, table of measurements, impulse and frequency response*||||

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# make sure the plot is displayed in this notebook
# %matplotlib inline
# specify the size of the plot
plt.rcParams['figure.figsize'] = (16, 6)

# for auto-reloading extenrnal modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# <h3 style="color:red;"><left>Exercise 2.1</left></h3>

# %% [markdown]
# **1. For each of these two signals, do the following on a blank sheet of paper (or type the equations in the Markdown cell if you are familiar with LaTex):**
# * **Compute the Fourier series expansion in the form**
# \begin{equation}
#     s(t)=a_0+\sum_{k=1}^\infty A_k\sin(2\pi kf_0t+\theta_k)
# \end{equation}
# where $f_0=\frac{1}{T_0}$.
#
#     **Hint :**You may want to use one of the following references:
#
#     Sec. 4.1 of “Digital Signal Processing”, by Proakis and Manolakis, 1996;
#
#     Sec. 4.2 of “Signals and Systems”, by A. Oppenheim and A. Willsky, 1983;
#
#     Sec. 3.3 of “Signals and Systems”, A. Oppenheim and A. Willsky, 1997.
#
#     Note that in the expression above, the function in the summation is $\sin(2\pi kf_0 t + \theta k )$, rather than a complex sinusoid. The formulas in the above references must be modified to accommodate this. You can compute the cos/sin version of the Fourier series, then convert the coefficients.

# %% [markdown]
# ![Capture.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![Capture.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **2. Write code to approximate the two signals using the Fourier series expansion above. Use 200 (instead of infinite number of) Sine waves. Then, plot these two signals.**

# %%
# write your code here
def S1(t):
  s = 0.5;
  i = np.arange(1, 200, 2)
  for k in i:
    s = s + (2/(np.pi*k)) * np.sin(np.pi * k * t)
  return s

t = np.arange(-100, 100 + 1, 1)
S1 = S1(t)
plt.plot(t,S1)
plt.title("Signal 1: Fourier Series Expansion")
plt.xlabel("t")
# Out:
# Text(0.5, 0, 't')

# %%
def S2(t):
  s = 0;
  i = np.arange(1, 201, 2)
  for k in i:
    if((k-1)%4 == 0):
      s = s + (2/(np.pi*k)) * np.sin(2* np.pi * k * t + np.pi/2)
    else:
      s = s + (-2/(np.pi*k)) * np.sin(2* np.pi * k * t + np.pi/2)
  return s

t = np.arange(-100, 100 + 1, 1)
S2 = S2(t)
plt.plot(t,S2)
plt.title("Signal 2: Fourier Series Expansion")
plt.xlabel("t")
# Out:
# Text(0.5, 0, 't')

# %% [markdown]
# <h3 style="color:red;"><left>Exercise 4.1</left></h3>

# %% [markdown]
# **1. Hand in plots of the Spectrum Analyzer output for each of the three synthesized waveforms.**

# %% [markdown]
# Signal 1

# %% [markdown]
# ![Capture.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Signal 2

# %% [markdown]
# ![Capture.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **2. For each case in Q1, comment on how the synthesized waveform differs from the desired signal,and on the structure of the spectral density.**

# %% [markdown]
# Signal 1 is reasonably close to our desired output.  There is a clear resemblance to a square wave with a pulse width of 1 and a period of 2.  It definitely needs more accumulated sine waves to be accurate though.
# Signal 2 on the other hand is no where close to resembling the desired output.  My best guess is that there is something wrong with my fourier series approximation.

# %% [markdown]
# <h3 style="color:red;"><left>Exercise 4.2</left></h3>

# %% [markdown]
# **1. Hand in plots of the output of the *Spectrum Analyzer* for each signal.**

# %% [markdown]
# Triangular pulse duration of 1 sec, period of 2 sec; modulating frequency of 10 Hz

# %% [markdown]
# ![lab3 4.2 1s2s10hJPG.JPG](data:image/jpeg;base64,...)insert your plots here

# %% [markdown]
# Triangular pulse duration of 1 sec, period of 2 sec; modulating frequency of 15 Hz

# %% [markdown]
# ![lab3 4.2 1s2s15hJPG.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Triangular pulse duration of 1 sec, period of 3 sec; modulating frequency of 10 Hz

# %% [markdown]
# ![lab3 4.2 1s3s10hJPG.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Triangular pulse duration of 1 sec, period of 6 sec; modulating frequency of 10 Hz

# %% [markdown]
# ![lab3 4.2 1s6s10hJPG.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **2. What effect does changing the modulating frequency have on the spectral density?**

# %% [markdown]
# The modulating frequency determines where the spectral density plot is centered.  When the modulating frequency is 10Hz, the spectral density plot is centered at 10Hz.

# %% [markdown]
# **3. Why does the spectrum have a comb structure and what is the spectral distance between impulses? Why?**

# %% [markdown]
# The spectrum has a comb structure because it's the result of the product between the triangle wave and the sine wave.  The spectral distance between impulses is directly related to the period of the triangle wave as a result.

# %% [markdown]
# **4. What would happen to the spectral density if the period of the triangle pulse were to
# increase toward infinity? (in the limit)**

# %% [markdown]
# We would see a single wide peak in the spectral density plot instead of multiple peaks.

# %% [markdown]
# <h3 style="color:red;"><left>Exercise 4.3</left></h3>

# %% [markdown]
# **1. Hand in the printout of the output of the Network Analyzer (magnitude and phase of the
# frequency response, and the impulse response).**

# %% [markdown]
# ![lab3 4.3.1.JPG](data:image/jpeg;base64,...)insert your printout here

# %% [markdown]
# **2. Hand in the plot of the impulse response obtained using a unit step.**

# %% [markdown]
# ![lab3 4.3.2.JPG](data:image/jpeg;base64,...)insert your plot here

# %% [markdown]
# **3. What are the advantages and disadvantages of each method?**

# %% [markdown]
# The advantage of the network analyzer is that it provides us with a phase and magnitude plot in addition to the impulse response.  The disadvantage of the network analyzer is that it features a lower resolution than the impulse response obtained using the unit step.  The advantage of the unit step method is that it results in a greater resolution plot.

# %% [markdown]
# <h3 style="color:red;"><left>Exercise 5.1</left></h3>

# %% [markdown]
# **1. Complete the follwing function that computes the DTFT of a discrete-time signal.**
# ```python
# def DTFT(x,n0,w):
#     """
#     This function computes the DTFT of a discrete-time signal.
#
#     Parameters
#     ---
#     x: the discrete-time signal
#     n0: time index corresponding to the 1st element of the x vector
#     w: frequencies
#
#     Returns
#     ---
#     X: the computed DTFT
#     """
#     pass
# ```
# **Note that if ```x``` is a vector of length $N$, then its DTFT is computed by**
#
# \begin{equation}
#     X(\omega)=\sum_{n=0}^{N-1}x[n]e^{-jw(n+n0)}
# \end{equation}
#
# **where $w$ is a vector that contains the frequencies from $-\pi$ to $\pi$.**
#
# **Hint:** In Python, ```1j``` is defined as $\sqrt{-1}$. Use `np.exp(x)` to calculate $e^x$.

# %%
# write your code here
def DTFT(x,n0,w):
  X = np.complex64(0)
  for n in range(0, len(x)):
    X = X + x[n] * np.exp(-1j * w * (n + n0))
  return X

# %% [markdown]
# **2. For the following signals**
#
# * $x[n]=\delta[n]$
# * $x[n]=\delta[n-5]$
# * $x[n]=(0.5)^nu[n]$
#
# **use your DTFT function to compute $X(\omega)$, and plots its magnitude and phase.**
#
# **Hint**: Use `np.power(a,b)` to calculate $a^b$. Use ```np.abs()``` and ```np.angle()``` to compute the magnitude and phase.

# %%
# write your code here
n = np.arange(-100, 100 + 1, 1)
n0 = n[0]
x1 = (n==0).astype(float)
x2 = ((n-5) == 0).astype(float)
x3 = np.power(0.5,n) * (n >= 0).astype(float)
w = np.linspace(-np.pi, np.pi, 201, endpoint=True)

X1 = DTFT(x1, n0, w)
X2 = DTFT(x2, n0, w)
X3 = DTFT(x3, n0, w)

plt.plot(w, (X1))
plt.title("Signal 1 DTFT")
plt.xlabel("w")
plt.show()

plt.plot(w, np.abs(X1))
plt.title("Signal 1 DTFT Magnitude")
plt.xlabel("w")
plt.show()

plt.plot(w, np.angle(X1))
plt.title("Signal 1 DTFT Phase")
plt.xlabel("w")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.plot(w, (X2))
plt.title("Signal 2 DTFT")
plt.xlabel("w")
plt.show()

plt.plot(w, np.abs(X2))
plt.title("Signal 2 DTFT Magnitude")
plt.xlabel("w")
plt.show()

plt.plot(w, np.angle(X2))
plt.title("Signal 2 DTFT Phase")
plt.xlabel("w")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.plot(w, (X3))
plt.title("Signal 3 DTFT")
plt.xlabel("w")
plt.show()

plt.plot(w, np.abs(X3))
plt.title("Signal 3 DTFT Magnitude")
plt.xlabel("w")
plt.show()

plt.plot(w, np.angle(X3))
plt.title("Signal 3 DTFT Phase")
plt.xlabel("w")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# <h3 style="color:red;"><left>Exercise 5.2: Magnitude and Phase of the Frequency Response of a Discrete-Time Systems</left></h3>

# %% [markdown]
# Consider the discrete-time system described by the following difference equation:
#
# \begin{equation}y[n]=0.9y[n-1]+0.3x[n]+0.24x[n-1]\end{equation}
#
# Assume that the system is **causal**.

# %% [markdown]
# **1. Draw a system diagram.**

# %% [markdown]
# ![Untitled Diagram-Page-4 (1).jpg](data:image/jpeg;base64,...)insert your diagram here

# %% [markdown]
# **2. Obtain the impulse response of the system by replacing $x[n]$ with $\delta[n]$ in the above equation. (Use causality to set up the initial conditions.)**

# %% [markdown]
# ![20230131_065756.jpg](data:image/jpeg;base64,...)write your answer here

# %% [markdown]
# **3. Use your answer in Q2 to obtain the frequency response of the system.**

# %% [markdown]
# write your answer here

# %% [markdown]
# **4. Find the frequency response of the system using another method. Specifically, take the DTFT of the left-hand-side and right-hand-side of the difference equation, and then use linearity and the time-shifting property of the DTFT along with the fact that $H(\omega)=\frac{Y(\omega)}{X(\omega)}$**

# %% [markdown]
# ![Capture.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **5. Write Python code to compute and plot the magnitude and phase responses, $|H(\omega)|$ and $\angle H(\omega)$, for $-\pi<\omega<\pi$.**

# %%
# write your code here
w = np.linspace(-np.pi, np.pi, 501)
H = (0.3 + 0.24 * np.exp(-1j * w)) / (1 - 0.9 * np.exp(-1j * w))
plt.plot(w, np.abs(H))
plt.title("5.2: Magnitude of H(w)")
plt.xlabel("w")
# Out:
# Text(0.5, 0, 'w')

# %%
plt.plot(w, np.angle(H))
plt.title("5.2: Angle of H(w)")
plt.xlabel("w")
# Out:
# Text(0.5, 0, 'w')

# %% [markdown]
# <h3 style="color:red;"><left>Exercise 5.3</left></h3>

# %% [markdown]
# **1. Insert the printout of your completed block diagram.**

# %% [markdown]
# ![Capture.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **2. Enter both the amplitude measurements you made and their theoretical values.**

# %% [markdown]
# | $\omega$ | Measurements | Theoretical Values |
# |:--------:|:------------:|:------------------:|
# | $\pi/16$ |      2.536        |         2.545           |
# |  $\pi/8$ |       1.373       |         1.382           |
# |  $\pi/4$ |       0.671      |             0.681       |

# %% [markdown]
# **3. Plot the impulse response, and the magnitude and phase of the frequency response by using your DTFT function.**

# %%
H = (0.3 + 0.24 * np.exp(-1j * w)) / (1 - 0.9 * np.exp(-1j * w))
w = np.linspace(-np.pi, np.pi, 601)
n = np.arange(-1000, 1000 + 1, 1)
n0 = n[0]
x16 = np.sin(np.pi/16 * n)
xw16 = DTFT(x16, n0, w)
yw16 = xw16 * H

plt.title("5.3: w = pi/16")
plt.xlabel("w")
plt.plot(w, yw16)
plt.show()
plt.title("5.3: w = pi/16 (magnitude)")
plt.xlabel("w")
plt.plot(w, np.abs(yw16))
plt.show()
plt.title("5.3: w = pi/16 (phase)")
plt.xlabel("w")
plt.plot(w, np.angle(yw16))
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
w = np.linspace(-np.pi, np.pi, 601)
n = np.arange(-1000, 1000 + 1, 1)
n0 = n[0]
x8 = np.sin(np.pi/8 * n)
xw8 = DTFT(x8, n0, w)
yw8 = xw8 * H

plt.title("5.3: w = pi/8")
plt.xlabel("w")
plt.plot(w, yw8)
plt.show()
plt.title("5.3: w = pi/8 (magnitude)")
plt.xlabel("w")
plt.plot(w, np.abs(yw8))
plt.show()
plt.title("5.3: w = pi/8 (phase)")
plt.xlabel("w")
plt.plot(w, np.angle(yw8))
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
w = np.linspace(-np.pi, np.pi, 601)
n = np.arange(-1000, 1000 + 1, 1)
n0 = n[0]
x4 = np.sin(np.pi/4 * n)
xw4 = DTFT(x4, n0, w)
yw4 = xw4 * H

plt.title("5.3: w = pi/4")
plt.xlabel("w")
plt.plot(w, yw4)
plt.show()
plt.title("5.3: w = pi/4 (magnitude)")
plt.xlabel("w")
plt.plot(w, np.abs(yw4))
plt.show()
plt.title("5.3: w = pi/4 (phase)")
plt.xlabel("w")
plt.plot(w, np.angle(yw4))
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
